# %% [markdown]
# # Distillation Report
#
# This notebook aggregates evaluation metrics, pairwise comparisons, and latency profiles.

# %% [markdown]
# ## 1. Perplexity
# - Load held-out corpora
# - Plot PPL (teacher vs student vs baseline)

# %% [markdown]
# ## 2. Task Metrics (lm-eval-harness)
# - ARC, HellaSwag, Winogrande
# - GSM8K few-shot if applicable

# %% [markdown]
# ## 3. Side-by-Side Preference
# - Pairwise win-rate
# - Error taxonomy

# %% [markdown]
# ## 4. Performance
# - Tokens/sec
# - Peak VRAM
